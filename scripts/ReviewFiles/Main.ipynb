# %% [markdown]
# # Review
#
# In this main notebook we will handle and organize the code needed to handle the reviews for the paper.

# %%
import numpy as np
import pandas as pd
import os
import shutil
import matplotlib.pyplot as plt

# %% [markdown]
# # 5 Proteins
#
# We first check for the 5 proteins case

# %%
whatprot_path= "/home/jkipen/whatprot/cc_code/bin/release/whatprot"
five_prot_rev_folder= "/raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/"
dye_seqs_path=five_prot_rev_folder + "dye-seqs.tsv"
WBlock_path = five_prot_rev_folder + "WithBlockEffect.json"
WithoutBlock_path = five_prot_rev_folder + "WithoutBlockEffect.json"
datasets_folder = five_prot_rev_folder + "Datasets/"
n_samples_per_dataset=100000;

# %%
## Simulating rad files
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    true_ids_path = folder_end + "true_ids_"+str(i)+".tsv";
    command = whatprot_path + " simulate rad -t 25 -g "+str(n_samples_per_dataset) +" -P "+ WBlock_path+" -S "+dye_seqs_path+" -R "+rad_path+" -Y "+true_ids_path;
    print(command)
    os.system(command)

for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    true_ids_path = folder_end + "true_ids_"+str(i)+".tsv";
    command = whatprot_path + " simulate rad -t 25 -g "+str(n_samples_per_dataset) +" -P "+ WithoutBlock_path+" -S "+dye_seqs_path+" -R "+rad_path+" -Y "+true_ids_path;
    print(command)
    os.system(command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_0.tsv
# Finished basic setup (0.000152334 seconds).
# Read 123 dye seqs (0.000172173 seconds).
# Finished generating 93578 radiometries (1.20659seconds).
# Finished saving results (7.80128 seconds).
# Total run time: 9.00825 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_1.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_2.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_3.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_4.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_5.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_6.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_7.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_8.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/true_ids_9.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_0.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_1.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_2.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_3.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_4.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_5.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_6.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_7.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_8.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 25 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/true_ids_9.tsv

# %%
## Simulating dye tracks
wo_block_dt_path=five_prot_rev_folder + "dye-tracks_wo_block.tsv";
w_block_dt_path=five_prot_rev_folder + "dye-tracks_w_block.tsv";
dye_tracks_wo_block_command = whatprot_path + " simulate dt -t 25 -g 1000 -P "+WithoutBlock_path+" -S "+dye_seqs_path+" -T "+wo_block_dt_path;
dye_tracks_w_block_command = whatprot_path + " simulate dt -t 25 -g 1000 -P "+WBlock_path+" -S "+dye_seqs_path+" -T "+w_block_dt_path;
print(dye_tracks_wo_block_command)
os.system(dye_tracks_wo_block_command)
print(dye_tracks_w_block_command)
os.system(dye_tracks_w_block_command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate dt -t 25 -g 1000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate dt -t 25 -g 1000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_w_block.tsv
# Finished basic setup (8.76188e-05 seconds).
# Read 123 dye seqs (9.68603e-05 seconds).
# Finished generating 115225 dye tracks (0.248563seconds).
# Finished deduping 26163 unique dye tracks (0.0620142seconds).
# Finished saving results (0.130173 seconds).
# Total run time: 0.440982 seconds.
# Finished basic setup (0.000133216 seconds).
# Read 123 dye seqs (0.000162466 seconds).
# Finished generating 115139 dye tracks (0.271004seconds).
# Finished deduping 29174 unique dye tracks (0.0645777seconds).
# Finished saving results (0.148107 seconds).
# Total run time: 0.484049 seconds.
# 0

# %%
## Doing all classifications (wo block):
for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    command = whatprot_path + " classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P "+ WithoutBlock_path+" -S "+dye_seqs_path+" -T "+wo_block_dt_path +" -R "+rad_path+" -Y "+pred_path;
    print(command)
    os.system(command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_0.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (0.000119925 seconds).
# Read 123 dye seqs (0.000166035 seconds).
# Read 26163 dye tracks (0.155956 seconds).
# Read 9335 radiometries (0.326834 seconds).
# Built classifier (0.0080285 seconds).
# Finished classification (8.34774 seconds).
# Finished saving results (0.00888674 seconds).
# Total run time: 8.84779 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_1.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.19475e-05 seconds).
# Read 123 dye seqs (0.00012376 seconds).
# Read 26163 dye tracks (0.126328 seconds).
# Read 9334 radiometries (0.314313 seconds).
# Built classifier (0.00805032 seconds).
# Finished classification (8.30287 seconds).
# Finished saving results (0.00804174 seconds).
# Total run time: 8.75984 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_2.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.94008e-05 seconds).
# Read 123 dye seqs (0.000106274 seconds).
# Read 26163 dye tracks (0.128173 seconds).
# Read 9354 radiometries (0.322098 seconds).
# Built classifier (0.00808903 seconds).
# Finished classification (8.34593 seconds).
# Finished saving results (0.00819967 seconds).
# Total run time: 8.81272 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_3.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.60416e-05 seconds).
# Read 123 dye seqs (0.000107808 seconds).
# Read 26163 dye tracks (0.130385 seconds).
# Read 9372 radiometries (0.317342 seconds).
# Built classifier (0.00803881 seconds).
# Finished classification (8.37808 seconds).
# Finished saving results (0.00871127 seconds).
# Total run time: 8.84278 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_4.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.63098e-05 seconds).
# Read 123 dye seqs (0.000107529 seconds).
# Read 26163 dye tracks (0.127856 seconds).
# Read 9325 radiometries (0.315386 seconds).
# Built classifier (0.00807943 seconds).
# Finished classification (8.31977 seconds).
# Finished saving results (0.00794458 seconds).
# Total run time: 8.77926 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_5.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (9.39695e-05 seconds).
# Read 123 dye seqs (0.000135028 seconds).
# Read 26163 dye tracks (0.129042 seconds).
# Read 9379 radiometries (0.31832 seconds).
# Built classifier (0.00808226 seconds).
# Finished classification (8.36499 seconds).
# Finished saving results (0.00810309 seconds).
# Total run time: 8.82882 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_6.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.89911e-05 seconds).
# Read 123 dye seqs (0.000106185 seconds).
# Read 26163 dye tracks (0.128583 seconds).
# Read 9353 radiometries (0.320688 seconds).
# Built classifier (0.00805542 seconds).
# Finished classification (8.3309 seconds).
# Finished saving results (0.00879976 seconds).
# Total run time: 8.79725 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_7.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (8.52197e-05 seconds).
# Read 123 dye seqs (0.000107577 seconds).
# Read 26163 dye tracks (0.129271 seconds).
# Read 9397 radiometries (0.319865 seconds).
# Built classifier (0.00804179 seconds).
# Finished classification (8.48972 seconds).
# Finished saving results (0.0070817 seconds).
# Total run time: 8.95422 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_8.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (9.37134e-05 seconds).
# Read 123 dye seqs (0.000147203 seconds).
# Read 26163 dye tracks (0.126637 seconds).
# Read 9362 radiometries (0.319 seconds).
# Built classifier (0.00809339 seconds).
# Finished classification (8.341 seconds).
# Finished saving results (0.00992217 seconds).
# Total run time: 8.80494 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WOBlock/Predictions_9.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (8.82512e-05 seconds).
# Read 123 dye seqs (0.000121908 seconds).
# Read 26163 dye tracks (0.128759 seconds).
# Read 9363 radiometries (0.316879 seconds).
# Built classifier (0.00801113 seconds).
# Finished classification (8.38081 seconds).
# Finished saving results (0.00963408 seconds).
# Total run time: 8.84435 seconds.

# %%
## Doing all classifications (w block):
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    command = whatprot_path + " classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P "+ WBlock_path+" -S "+dye_seqs_path+" -T "+wo_block_dt_path +" -R "+rad_path+" -Y "+pred_path;
    print(command)
    os.system(command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_0.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (0.000115563 seconds).
# Read 123 dye seqs (0.000167087 seconds).
# Read 26163 dye tracks (0.157314 seconds).
# Read 9346 radiometries (0.321618 seconds).
# Built classifier (0.00809883 seconds).
# Finished classification (8.49303 seconds).
# Finished saving results (0.00911501 seconds).
# Total run time: 8.98952 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_1.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (9.21842e-05 seconds).
# Read 123 dye seqs (0.000134142 seconds).
# Read 26163 dye tracks (0.128379 seconds).
# Read 9351 radiometries (0.316191 seconds).
# Built classifier (0.00800315 seconds).
# Finished classification (8.39658 seconds).
# Finished saving results (0.0124511 seconds).
# Total run time: 8.86188 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_2.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (0.000105849 seconds).
# Read 123 dye seqs (0.000143697 seconds).
# Read 26163 dye tracks (0.127221 seconds).
# Read 9378 radiometries (0.31964 seconds).
# Built classifier (0.00807601 seconds).
# Finished classification (8.42606 seconds).
# Finished saving results (0.00813316 seconds).
# Total run time: 8.88943 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_3.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (9.3352e-05 seconds).
# Read 123 dye seqs (0.000133519 seconds).
# Read 26163 dye tracks (0.129359 seconds).
# Read 9391 radiometries (0.319507 seconds).
# Built classifier (0.00805433 seconds).
# Finished classification (8.451 seconds).
# Finished saving results (0.00701681 seconds).
# Total run time: 8.91521 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_4.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (9.79574e-05 seconds).
# Read 123 dye seqs (0.00013452 seconds).
# Read 26163 dye tracks (0.127827 seconds).
# Read 9389 radiometries (0.318566 seconds).
# Built classifier (0.00804551 seconds).
# Finished classification (8.4645 seconds).
# Finished saving results (0.00849935 seconds).
# Total run time: 8.92771 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_5.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (8.68598e-05 seconds).
# Read 123 dye seqs (0.000125847 seconds).
# Read 26163 dye tracks (0.129065 seconds).
# Read 9402 radiometries (0.321201 seconds).
# Built classifier (0.00802533 seconds).
# Finished classification (8.46545 seconds).
# Finished saving results (0.00958773 seconds).
# Total run time: 8.93359 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_6.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (0.000127686 seconds).
# Read 123 dye seqs (0.000219845 seconds).
# Read 26163 dye tracks (0.128902 seconds).
# Read 9378 radiometries (0.319231 seconds).
# Built classifier (0.00874742 seconds).
# Finished classification (8.40738 seconds).
# Finished saving results (0.00907326 seconds).
# Total run time: 8.87373 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_7.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (8.00891e-05 seconds).
# Read 123 dye seqs (0.000106788 seconds).
# Read 26163 dye tracks (0.128283 seconds).
# Read 9357 radiometries (0.317123 seconds).
# Built classifier (0.00804294 seconds).
# Finished classification (8.31555 seconds).
# Finished saving results (0.00920997 seconds).
# Total run time: 8.77844 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_8.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.86055e-05 seconds).
# Read 123 dye seqs (0.000112547 seconds).
# Read 26163 dye tracks (0.12741 seconds).
# Read 9356 radiometries (0.314468 seconds).
# Built classifier (0.00803061 seconds).
# Finished classification (8.43499 seconds).
# Finished saving results (0.00932868 seconds).
# Total run time: 8.89446 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 1000 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/5Prot/Datasets/WBlock/Predictions_9.tsv
# Using OpenMP with 40 threads.
# Finished basic setup (7.64886e-05 seconds).
# Read 123 dye seqs (0.000106601 seconds).
# Read 26163 dye tracks (0.128296 seconds).
# Read 9360 radiometries (0.314509 seconds).
# Built classifier (0.00812171 seconds).
# Finished classification (8.27973 seconds).
# Finished saving results (0.00697576 seconds).
# Total run time: 8.73786 seconds.

# %%
def analyze_whatprot_results(path_pred,path_true_label):
    df_pred=pd.read_csv(path_pred)
    est_labels=df_pred["best_pep_iz"].to_numpy().flatten()
    df_true=pd.read_csv(path_true_label,header=None,skiprows=1)
    true_labels=df_true.to_numpy().flatten()
    accuracy = np.mean(est_labels == true_labels)
    return accuracy;

# %%
accs_wo_block=[];
for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    path_true_label = folder_end + "true_ids_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    accs_wo_block.append(analyze_whatprot_results(pred_path,path_true_label))
accs_w_block=[];
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    path_true_label = folder_end + "true_ids_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    accs_w_block.append(analyze_whatprot_results(pred_path,path_true_label))

# %%
print(np.mean(accs_wo_block)*100)
print(np.std(accs_wo_block)*100)
print(np.mean(accs_w_block)*100)
print(np.std(accs_w_block)*100)
# Out:
# 62.577351759215524
# 0.28565549922207145
# 56.36286557382218
# 0.6354082818807745

# %% [markdown]
# We can observe that whatprot becomes 10% less accurate (drop of 6% in accuracy). Lets see what happens for the whole proteome.
#
# # Whole proteome
#
# Now lets check for the whole proteome setting

# %%
whatprot_path= "/home/jkipen/whatprot/cc_code/bin/release/whatprot"
whole_prot_rev_folder= "/raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/"
dye_seqs_path=whole_prot_rev_folder + "dye-seqs.tsv"
WBlock_path = whole_prot_rev_folder + "WithBlockEffect.json"
WithoutBlock_path = whole_prot_rev_folder + "WithoutBlockEffect.json"
datasets_folder = whole_prot_rev_folder + "Datasets/"
omp_thread_command = "export OMP_NUM_THREADS=30 \n"
n_samples_per_dataset=100000; #Check after if we need more

# %%
## Simulating rad files
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    true_ids_path = folder_end + "true_ids_"+str(i)+".tsv";
    command = whatprot_path + " simulate rad -t 40 -g "+str(n_samples_per_dataset) +" -P "+ WBlock_path+" -S "+dye_seqs_path+" -R "+rad_path+" -Y "+true_ids_path;
    print(command)
    os.system(command)

for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    true_ids_path = folder_end + "true_ids_"+str(i)+".tsv";
    command = whatprot_path + " simulate rad -t 40 -g "+str(n_samples_per_dataset) +" -P "+ WithoutBlock_path+" -S "+dye_seqs_path+" -R "+rad_path+" -Y "+true_ids_path;
    print(command)
    os.system(command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_0.tsv
# Finished basic setup (0.000147047 seconds).
# Read 152291 dye seqs (0.110748 seconds).
# Finished generating 94891 radiometries (1.97164seconds).
# Finished saving results (12.8061 seconds).
# Total run time: 14.8887 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_1.tsv
# Finished basic setup (0.000150187 seconds).
# Read 152291 dye seqs (0.112912 seconds).
# Finished generating 94967 radiometries (1.97492seconds).
# Finished saving results (12.7787 seconds).
# Total run time: 14.8667 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_2.tsv
# Finished basic setup (7.05998e-05 seconds).
# Read 152291 dye seqs (0.0910362 seconds).
# Finished generating 94915 radiometries (1.95127seconds).
# Finished saving results (12.776 seconds).
# Total run time: 14.8184 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_3.tsv
# Finished basic setup (0.000144282 seconds).
# Read 152291 dye seqs (0.111672 seconds).
# Finished generating 94921 radiometries (1.97512seconds).
# Finished saving results (12.7527 seconds).
# Total run time: 14.8397 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_4.tsv
# Finished basic setup (0.000127107 seconds).
# Read 152291 dye seqs (0.109184 seconds).
# Finished generating 94861 radiometries (1.98232seconds).
# Finished saving results (12.7378 seconds).
# Total run time: 14.8295 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_5.tsv
# Finished basic setup (0.000141376 seconds).
# Read 152291 dye seqs (0.112177 seconds).
# Finished generating 94766 radiometries (1.96678seconds).
# Finished saving results (12.7014 seconds).
# Total run time: 14.7805 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_6.tsv
# Finished basic setup (0.000140226 seconds).
# Read 152291 dye seqs (0.112455 seconds).
# Finished generating 95039 radiometries (1.98657seconds).
# Finished saving results (12.8353 seconds).
# Total run time: 14.9346 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_7.tsv
# Finished basic setup (8.35741e-05 seconds).
# Read 152291 dye seqs (0.10647 seconds).
# Finished generating 95006 radiometries (1.97958seconds).
# Finished saving results (12.7717 seconds).
# Total run time: 14.8579 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_8.tsv
# Finished basic setup (0.000138449 seconds).
# Read 152291 dye seqs (0.111358 seconds).
# Finished generating 94921 radiometries (1.97311seconds).
# Finished saving results (12.7195 seconds).
# Total run time: 14.8042 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/true_ids_9.tsv
# Finished basic setup (0.000137377 seconds).
# Read 152291 dye seqs (0.113473 seconds).
# Finished generating 94993 radiometries (1.97288seconds).
# Finished saving results (12.7533 seconds).
# Total run time: 14.8399 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_0.tsv
# Finished basic setup (0.000150231 seconds).
# Read 152291 dye seqs (0.112498 seconds).
# Finished generating 95085 radiometries (1.96546seconds).
# Finished saving results (12.8205 seconds).
# Total run time: 14.8987 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_1.tsv
# Finished basic setup (0.000142429 seconds).
# Read 152291 dye seqs (0.112388 seconds).
# Finished generating 94934 radiometries (1.96613seconds).
# Finished saving results (12.6878 seconds).
# Total run time: 14.7665 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_2.tsv
# Finished basic setup (7.44825e-05 seconds).
# Read 152291 dye seqs (0.0912869 seconds).
# Finished generating 94946 radiometries (1.94269seconds).
# Finished saving results (12.7159 seconds).
# Total run time: 14.75 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_3.tsv
# Finished basic setup (7.16876e-05 seconds).
# Read 152291 dye seqs (0.0910134 seconds).
# Finished generating 95072 radiometries (1.94357seconds).
# Finished saving results (12.793 seconds).
# Total run time: 14.8278 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_4.tsv
# Finished basic setup (0.000137343 seconds).
# Read 152291 dye seqs (0.111553 seconds).
# Finished generating 94938 radiometries (1.94101seconds).
# Finished saving results (12.6979 seconds).
# Total run time: 14.7506 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_5.tsv
# Finished basic setup (0.000135769 seconds).
# Read 152291 dye seqs (0.112576 seconds).
# Finished generating 94977 radiometries (1.96018seconds).
# Finished saving results (12.7209 seconds).
# Total run time: 14.7938 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_6.tsv
# Finished basic setup (0.000135319 seconds).
# Read 152291 dye seqs (0.110792 seconds).
# Finished generating 94947 radiometries (1.95604seconds).
# Finished saving results (12.7502 seconds).
# Total run time: 14.8172 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_7.tsv
# Finished basic setup (0.000119269 seconds).
# Read 152291 dye seqs (0.0950739 seconds).
# Finished generating 94861 radiometries (1.94116seconds).
# Finished saving results (12.724 seconds).
# Total run time: 14.7604 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_8.tsv
# Finished basic setup (0.000135622 seconds).
# Read 152291 dye seqs (0.11376 seconds).
# Finished generating 94963 radiometries (1.95937seconds).
# Finished saving results (12.758 seconds).
# Total run time: 14.8313 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 100000 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/true_ids_9.tsv
# Finished basic setup (0.000135502 seconds).
# Read 152291 dye seqs (0.110839 seconds).
# Finished generating 94962 radiometries (1.945seconds).
# Finished saving results (12.8262 seconds).
# Total run time: 14.8823 seconds.

# %%
## Simulating dye tracks
wo_block_dt_path=whole_prot_rev_folder + "dye-tracks_wo_block.tsv";
w_block_dt_path=whole_prot_rev_folder + "dye-tracks_w_block.tsv";
dye_tracks_wo_block_command = whatprot_path + " simulate dt -t 40 -g 250 -P "+ WithoutBlock_path +" -S "+dye_seqs_path+" -T "+wo_block_dt_path;
dye_tracks_w_block_command = whatprot_path + " simulate dt -t 40 -g 250 -P "+ WBlock_path +" -S "+dye_seqs_path+" -T "+w_block_dt_path;
print(dye_tracks_wo_block_command)
os.system(dye_tracks_wo_block_command)
print(dye_tracks_w_block_command)
os.system(dye_tracks_w_block_command)
# Out:
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate dt -t 40 -g 250 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv
# Finished basic setup (0.000142126 seconds).
# Read 152291 dye seqs (0.113656 seconds).
# Finished generating 36160771 dye tracks (123.184seconds).
# Finished deduping 10609203 unique dye tracks (240.281seconds).
# Finished saving results (87.746 seconds).
# Total run time: 451.324 seconds.
# /home/jkipen/whatprot/cc_code/bin/release/whatprot simulate dt -t 40 -g 250 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_w_block.tsv
# Finished basic setup (7.11875e-05 seconds).
# Read 152291 dye seqs (0.0896716 seconds).
# Finished generating 36159340 dye tracks (128.577seconds).
# Finished deduping 11281969 unique dye tracks (241.613seconds).
# Finished saving results (93.9724 seconds).
# Total run time: 464.253 seconds.
# 0

# %%
## Doing all classifications (wo block):
omp_thread_command = "export OMP_NUM_THREADS=20 \n"
for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    command = omp_thread_command + whatprot_path + " classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P "+ WithoutBlock_path+" -S "+dye_seqs_path+" -T "+wo_block_dt_path +" -R "+rad_path+" -Y "+pred_path;
    print(command)
    os.system(command)
# Out:
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_0.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (9.24598e-05 seconds).
# Read 152291 dye seqs (0.133488 seconds).
# Read 10609203 dye tracks (81.0983 seconds).
# Read 95085 radiometries (5.19334 seconds).
# Built classifier (36.3204 seconds).
# Finished classification (4475.43 seconds).
# Finished saving results (0.0717572 seconds).
# Total run time: 4598.25 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_1.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000118027 seconds).
# Read 152291 dye seqs (0.112538 seconds).
# Read 10609203 dye tracks (79.7997 seconds).
# Read 94934 radiometries (5.1675 seconds).
# Built classifier (35.5979 seconds).
# Finished classification (4445.73 seconds).
# Finished saving results (0.130457 seconds).
# Total run time: 4566.54 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_2.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000122301 seconds).
# Read 152291 dye seqs (0.11184 seconds).
# Read 10609203 dye tracks (79.3173 seconds).
# Read 94946 radiometries (5.09372 seconds).
# Built classifier (34.8873 seconds).
# Finished classification (4157.56 seconds).
# Finished saving results (0.0687393 seconds).
# Total run time: 4277.04 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_3.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000113806 seconds).
# Read 152291 dye seqs (0.113986 seconds).
# Read 10609203 dye tracks (79.8788 seconds).
# Read 95072 radiometries (5.13536 seconds).
# Built classifier (35.0769 seconds).
# Finished classification (4163.89 seconds).
# Finished saving results (0.0696286 seconds).
# Total run time: 4284.16 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_4.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000124486 seconds).
# Read 152291 dye seqs (0.11096 seconds).
# Read 10609203 dye tracks (79.9287 seconds).
# Read 94938 radiometries (5.14511 seconds).
# Built classifier (35.4777 seconds).
# Finished classification (4091.52 seconds).
# Finished saving results (0.0746264 seconds).
# Total run time: 4212.26 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_5.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (9.84902e-05 seconds).
# Read 152291 dye seqs (0.110189 seconds).
# Read 10609203 dye tracks (79.2069 seconds).
# Read 94977 radiometries (5.14889 seconds).
# Built classifier (36.5122 seconds).
# Finished classification (4148 seconds).
# Finished saving results (0.10679 seconds).
# Total run time: 4269.08 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_6.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.00053804 seconds).
# Read 152291 dye seqs (0.107545 seconds).
# Read 10609203 dye tracks (80.4331 seconds).
# Read 94947 radiometries (5.14739 seconds).
# Built classifier (35.2335 seconds).
# Finished classification (4098.09 seconds).
# Finished saving results (0.0742848 seconds).
# Total run time: 4219.09 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithoutBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WOBlock/Predictions_7.tsv

# %%
for i in range(7,10):
    print(i)
# Out:
# 7
# 8
# 9

# %%
## Doing all classifications (w block):
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    rad_path = folder_end + "Radiometries_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    command = omp_thread_command + whatprot_path + " classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P "+ WBlock_path+" -S "+dye_seqs_path+" -T "+wo_block_dt_path +" -R "+rad_path+" -Y "+pred_path;
    print(command)
    os.system(command)
# Out:
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_0.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000297399 seconds).
# Read 152291 dye seqs (0.0885319 seconds).
# Read 10609203 dye tracks (79.5629 seconds).
# Read 94891 radiometries (5.09795 seconds).
# Built classifier (34.9436 seconds).
# Finished classification (4308.58 seconds).
# Finished saving results (0.0695041 seconds).
# Total run time: 4428.34 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_1.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000114846 seconds).
# Read 152291 dye seqs (0.11213 seconds).
# Read 10609203 dye tracks (79.3186 seconds).
# Read 94967 radiometries (5.09919 seconds).
# Built classifier (34.9199 seconds).
# Finished classification (4331.04 seconds).
# Finished saving results (0.0709278 seconds).
# Total run time: 4450.56 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_2.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000122871 seconds).
# Read 152291 dye seqs (0.111791 seconds).
# Read 10609203 dye tracks (79.146 seconds).
# Read 94915 radiometries (5.0991 seconds).
# Built classifier (34.8791 seconds).
# Finished classification (4327.07 seconds).
# Finished saving results (0.0723295 seconds).
# Total run time: 4446.38 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_3.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (7.08429e-05 seconds).
# Read 152291 dye seqs (0.100149 seconds).
# Read 10609203 dye tracks (79.8998 seconds).
# Read 94921 radiometries (5.18301 seconds).
# Built classifier (35.4015 seconds).
# Finished classification (4336.75 seconds).
# Finished saving results (0.0652579 seconds).
# Total run time: 4457.4 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_4.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000105301 seconds).
# Read 152291 dye seqs (0.112015 seconds).
# Read 10609203 dye tracks (79.2439 seconds).
# Read 94861 radiometries (5.10264 seconds).
# Built classifier (34.9142 seconds).
# Finished classification (4351.56 seconds).
# Finished saving results (0.0717158 seconds).
# Total run time: 4471.01 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_5.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.00012112 seconds).
# Read 152291 dye seqs (0.114224 seconds).
# Read 10609203 dye tracks (79.304 seconds).
# Read 94766 radiometries (5.11137 seconds).
# Built classifier (35.4628 seconds).
# Finished classification (4341.76 seconds).
# Finished saving results (0.0747553 seconds).
# Total run time: 4461.83 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_6.tsv
# Using OpenMP with 20 threads.
# Finished basic setup (0.000117948 seconds).
# Read 152291 dye seqs (0.112224 seconds).
# Read 10609203 dye tracks (79.8487 seconds).
# Read 95039 radiometries (5.13004 seconds).
# Built classifier (34.9889 seconds).
# Finished classification (4353.83 seconds).
# Finished saving results (0.0689661 seconds).
# Total run time: 4473.98 seconds.
# export OMP_NUM_THREADS=20
# /home/jkipen/whatprot/cc_code/bin/release/whatprot classify hybrid -k 10000 -s 0.5 -H 500 -p 5 -P /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/WithBlockEffect.json -S /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-seqs.tsv -T /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/dye-tracks_wo_block.tsv -R /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/Reviews/BlockEffect/WholeProteome/Datasets/WBlock/Predictions_7.tsv

# %%
accs_wo_block=[];
for i in range(10):
    folder_end=datasets_folder + "WOBlock/"
    path_true_label = folder_end + "true_ids_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    accs_wo_block.append(analyze_whatprot_results(pred_path,path_true_label))
accs_w_block=[];
for i in range(10):
    folder_end=datasets_folder + "WBlock/"
    path_true_label = folder_end + "true_ids_"+str(i)+".tsv";
    pred_path = folder_end + "Predictions_"+str(i)+".tsv";
    accs_w_block.append(analyze_whatprot_results(pred_path,path_true_label))
# Out:
# KeyboardInterrupt

# %%
print(np.mean(accs_wo_block)*100)
print(np.std(accs_wo_block)*100)
print(np.mean(accs_w_block)*100)
print(np.std(accs_w_block)*100)

# %% [markdown]
# #
#
# Calculate KL Divergence of the methods.
# Increase the font size of the pictures!
