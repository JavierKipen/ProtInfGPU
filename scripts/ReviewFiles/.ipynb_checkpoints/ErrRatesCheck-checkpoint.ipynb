# %% [markdown]
# # Error rates verification
#
# In this notebook I generate all the datasets needed to check the different error rates, as asked in the review. Lets take it step by step
#
# ## Generating radiometries
#
# First step is to generate radiometries with the error rates mentioned.

# %%
import numpy as np
import pandas as pd
import os
import shutil
import matplotlib.pyplot as plt

# %%
whatprot_path= "/../../ext/whatprot/cc_code/bin/release/whatprot"
common_path_datasets= "/raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/"
dye_seqs_path=common_path_datasets + "dye-seqs.tsv"
Div2_path=common_path_datasets+"Div2/";Div5_path=common_path_datasets+"Div5/";Div10_path=common_path_datasets+"Div10/";
Divs_paths=[Div2_path,Div5_path,Div10_path];
ErrParamsJsonFile="ErrParams.json"

# %%
n_samples_per_dataset=10000000; 
n_multidatasets=10;
#for j in range(len(Divs_paths)):
for j in range(1): #We start with only doing the process for one path to check!
    div_path=Divs_paths[j];
    for i in range(n_multidatasets):
        param_path=div_path+ErrParamsJsonFile;
        rad_path = div_path+ "MultiDatasets/radiometries_"+str(i)+".tsv";
        true_ids_path = div_path+ "MultiDatasets/true-ids_"+str(i)+".tsv";
        command = "." +whatprot_path + " simulate rad -t 40 -g "+str(n_samples_per_dataset) +" -P "+ param_path+" -S "+dye_seqs_path+" -R "+rad_path+" -Y "+true_ids_path;
        print(command)
        os.system(command)
# Out:
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_0.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_0.tsv
# Finished basic setup (0.000137759 seconds).
# Read 152291 dye seqs (0.111577 seconds).
# Finished generating 9748671 radiometries (203.89seconds).
# Finished saving results (1591.46 seconds).
# Total run time: 1795.46 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_1.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_1.tsv
# Finished basic setup (0.000110781 seconds).
# Read 152291 dye seqs (0.144231 seconds).
# Finished generating 9748429 radiometries (231.058seconds).
# Finished saving results (1841.39 seconds).
# Total run time: 2072.6 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_2.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_2.tsv
# Finished basic setup (0.000115594 seconds).
# Read 152291 dye seqs (0.166126 seconds).
# Finished generating 9748418 radiometries (237.782seconds).
# Finished saving results (1671.46 seconds).
# Total run time: 1909.41 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_3.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_3.tsv
# Finished basic setup (0.000107018 seconds).
# Read 152291 dye seqs (0.145289 seconds).
# Finished generating 9748994 radiometries (218.511seconds).
# Finished saving results (1668.6 seconds).
# Total run time: 1887.26 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_4.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_4.tsv
# Finished basic setup (0.000120126 seconds).
# Read 152291 dye seqs (0.148622 seconds).
# Finished generating 9748637 radiometries (222.876seconds).
# Finished saving results (1581.93 seconds).
# Total run time: 1804.96 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_5.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_5.tsv
# Finished basic setup (8.35909e-05 seconds).
# Read 152291 dye seqs (0.0973997 seconds).
# Finished generating 9748675 radiometries (215.794seconds).
# Finished saving results (1862.01 seconds).
# Total run time: 2077.91 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_6.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_6.tsv
# Finished basic setup (0.000105953 seconds).
# Read 152291 dye seqs (0.140753 seconds).
# Finished generating 9748701 radiometries (260.152seconds).
# Finished saving results (1858.44 seconds).
# Total run time: 2118.74 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_7.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_7.tsv
# Finished basic setup (0.000107558 seconds).
# Read 152291 dye seqs (0.164849 seconds).
# Finished generating 9748407 radiometries (219.298seconds).
# Finished saving results (1945.4 seconds).
# Total run time: 2164.86 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_8.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_8.tsv
# Finished basic setup (0.000111959 seconds).
# Read 152291 dye seqs (0.141216 seconds).
# Finished generating 9748695 radiometries (225.714seconds).
# Finished saving results (1881.86 seconds).
# Total run time: 2107.72 seconds.
# ./../../ext/whatprot/cc_code/bin/release/whatprot simulate rad -t 40 -g 10000000 -P /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/ErrParams.json -S /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/dye-seqs.tsv -R /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/radiometries_9.tsv -Y /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/MultiDatasets/true-ids_9.tsv
# Finished basic setup (0.000114661 seconds).
# Read 152291 dye seqs (0.152916 seconds).
# Finished generating 9748769 radiometries (213.281seconds).
# Finished saving results (1776.05 seconds).
# Total run time: 1989.48 seconds.

# %%
#Do this for each dataset, grabs much memory.
div_path=Divs_paths[0];
dfs = [] 
for i in range(n_multidatasets):  #Groups multidatasets in one big dataset
    dfr = pd.read_csv(div_path+ "MultiDatasets/radiometries_"+str(i)+".tsv", sep="\t", header=None, skiprows=3); #Skipping metadata rows
    dft = pd.read_csv(div_path+ "MultiDatasets/true-ids_"+str(i)+".tsv", sep="\t", header=None, skiprows=1); #Skipping metadata rows
    dfr['true_ids'] = dft[0]
    dfs.append(dfr)
    
big_df = pd.concat(dfs, axis=0, ignore_index=True)
result_df = big_df.groupby('true_ids', group_keys=False).apply(lambda group: group.head(100)) #Saves only 100 samples per dye seq.

del big_df

result_df.to_csv(div_path+"aux.csv", index=False)

radiometries_df = result_df.drop(columns=['true_ids'])
true_ids_series = result_df['true_ids']

# Get the number of reads (rows) from the filtered data
num_reads = len(result_df)
# Save the final radiometries file with custom header
num_timesteps = 40   # Given constant: number of timesteps
num_channels = 3     # Given constant: number of channels
# Save the final true IDs file with custom header (only number of reads)
true_ids_output_file = div_path+"true-ids.tsv"
with open(true_ids_output_file, "w") as f:
    f.write(f"{num_reads}\n")
    true_ids_series.to_csv(f, sep="\t", index=False, header=False)
    
radiometries_output_file = div_path+"radiometries.tsv"
with open(radiometries_output_file, "w") as f:
    f.write(f"{num_timesteps}\n")
    f.write(f"{num_channels}\n")
    f.write(f"{num_reads}\n")
    radiometries_df.to_csv(f, sep="\t", index=False, header=False)
##Now lets do the reduced dataset
reduced_path=div_path+"Reduced/"; #We will saved the reduced in other folder
df_small = result_df.groupby('true_ids', group_keys=False).apply(lambda group: group.head(2))
num_reads = len(df_small) #Update number of points

radiometries_df_s = df_small.drop(columns=['true_ids'])
true_ids_series_s = df_small['true_ids']

true_ids_output_file = reduced_path+"true-ids.tsv"
with open(true_ids_output_file, "w") as f:
    f.write(f"{num_reads}\n")
    true_ids_series_s.to_csv(f, sep="\t", index=False, header=False)
    
radiometries_output_file = reduced_path+"radiometries.tsv"
with open(radiometries_output_file, "w") as f:
    f.write(f"{num_timesteps}\n")
    f.write(f"{num_channels}\n")
    f.write(f"{num_reads}\n")
    radiometries_df_s.to_csv(f, sep="\t", index=False, header=False)

# %%
del result_df
del radiometries_df
del true_ids_series

# %% [markdown]
# ## Run Probeam on radiometries
# Now we get the sparse scores with Probeam:

# %%
probeam_exec_names=["probeamDiv2","probeamDiv5","probeamDiv10"] #A name for each with reduced error. 
probeam_exec_folder="../../ext/probeam/"

div_index=0;

div_path = Divs_paths[div_index]; #Select err div we want.
probeam_exec = probeam_exec_folder + probeam_exec_names[div_index];

rads_path=div_path+"radiometries.tsv"
reduced_rads_path=div_path+"Reduced/radiometries.tsv"
#Commands to run probeam on df and reduced df:
print(probeam_exec + " "  + rads_path + " -b 30 -s 1000")
print(probeam_exec + " "  + reduced_rads_path + " -b 30 -s 1000")

# %% [markdown]
# Running this code accordingly we get TopScores & TopScoresId for each div (and reduced).
#
# ## Generating datasets for protein inference check
#
# Generate first the datasets by running DatasetExporterWhatprot in code/exporting. I have modified below to make it with the data for this project itself.

# %% [markdown]
# Then run the Oracle with these new datasets:

# %%
#./opt.out /raid/jkipen/ProtInfGPU/data/Reviews/ErrRates/Div2/binary/ProbeamW2 /home/jkipen/ProtInfGPU/results/Review/Div2Red -d 0 -e 30 -c 1 -m 120 -M 30 -t 1024 -o 1 -n 1000

# %% [markdown]
# Once it is working and seems fine, copy the TopNscores and TpoNScoresIds into the respective folders with:

# %%
#Reduced
cp /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/Reduced/TopNScores.bin /raid/jkipen/ProtInfGPU/data/Reviews/ErrRates/Div2/binary/ProbeamW2/Common/TopNScores.bin
cp /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/Reduced/TopNScoresId.bin /raid/jkipen/ProtInfGPU/data/Reviews/ErrRates/Div2/binary/ProbeamW2/Common/TopNScoresId.bin

#Full
cp /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/TopNScores.bin /raid/jkipen/ProtInfGPU/data/Reviews/ErrRates/Div2/binary/ProbeamW100/Common/TopNScores.bin
cp /raid/jkipen/ProtInfGPU/data/WhatprotGen/Review/Div2/TopNScoresId.bin /raid/jkipen/ProtInfGPU/data/Reviews/ErrRates/Div2/binary/ProbeamW100/Common/TopNScoresId.bin

# %% [markdown]
# Finally run the full protein inference with

# %%
./opt.out /home/jkipen/raid_storage/ProtInfGPU/data/20642_Prot/binary/ProbeamBetterConfig /home/jkipen/ProtInfGPU/results/20642_Prot/Tests -d 0 -e 3 -c 1 -m 120 -M 30 -t 1024 -n 1000
